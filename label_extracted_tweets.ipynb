# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_excel(r'C:/Users/Naman Bhoj/Desktop/Feb-April/in process 2021/cicn 2 mayank/extracted data.xlsx')

# %%
# we extracted the tweets and then used sentiwordnet to label those tweets as having positive sentiment or negative sentiment

# %%
dataset
# Out:
#                  Tweet Id                                               Text  \
# 0     1378654719166529540  RT @MAhealthforkids : It’s not only #pediatric...
# 1     1378654639214768129  RT @ger_majesty : I was so angry I made a sket...
# 2     1378654614539665412  RT @SteveCameronPr1 : Former #Jeopardy contest...
# 3     1378654597057638402  RT @hotvickkrishna : How the mRNA Vaccine (Mod...
# 4     1378654537033117698  RT @hotvickkrishna : How the mRNA Vaccine (Mod...
# ...                   ...                                                ...
# 2053  1378512268980150276  RT @SanjayMehta_ : #computer लिया. वायरस आया. ...
# 2054  1378512253096443909  🚨Alas this continues to happen! Just TODAY ano...
# 2055  1378512142077464577  RT @Redpainter1 : I fully support your right t...
# 2056  1378512057440464901  RT @MoHFW_INDIA : #LargestVaccineDrive \n\nMor...
# 2057  1378511808965775361  I had a migraine every day after my first covi...
#
# ...

# %%
import nltk

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Naman
# [nltk_data]     Bhoj\AppData\Roaming\nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()

# %%
a = 'I am very happpy that he got hurt'

# %%
b = 'I am happy he is safe'

# %%
sid.polarity_scores(a)
# Out:
# {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'compound': -0.5267}

# %%
sid.polarity_scores(b)
# Out:
# {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'compound': 0.765}

# %%
dataset['scores'] = dataset['Text'].apply(lambda Text: sid.polarity_scores(Text))

# %%
# the above line gives us the new column called as scores, we will only use the compoung score

# %%
dataset['compound_score'] = dataset['scores'].apply(lambda d: d['compound'])

# %% [markdown]
# dataset['Text'].iloc[14]

# %%
dataset['sentiment'] =  dataset['compound_score'].apply(lambda score: 1 if score >=0 else 0)

# %%
dataset
# Out:
#                  Tweet Id                                               Text  \
# 0     1378654719166529540  RT @MAhealthforkids : It’s not only #pediatric...
# 1     1378654639214768129  RT @ger_majesty : I was so angry I made a sket...
# 2     1378654614539665412  RT @SteveCameronPr1 : Former #Jeopardy contest...
# 3     1378654597057638402  RT @hotvickkrishna : How the mRNA Vaccine (Mod...
# 4     1378654537033117698  RT @hotvickkrishna : How the mRNA Vaccine (Mod...
# ...                   ...                                                ...
# 2053  1378512268980150276  RT @SanjayMehta_ : #computer लिया. वायरस आया. ...
# 2054  1378512253096443909  🚨Alas this continues to happen! Just TODAY ano...
# 2055  1378512142077464577  RT @Redpainter1 : I fully support your right t...
# 2056  1378512057440464901  RT @MoHFW_INDIA : #LargestVaccineDrive \n\nMor...
# 2057  1378511808965775361  I had a migraine every day after my first covi...
#
# ...

# %%
dataset.drop(['compound_score', 'scores'], axis = 1, inplace = True)

# %%
dataset
# Out:
#                  Tweet Id                                               Text  \
# 0     1378654719166529540  RT @MAhealthforkids : It’s not only #pediatric...
# 1     1378654639214768129  RT @ger_majesty : I was so angry I made a sket...
# 2     1378654614539665412  RT @SteveCameronPr1 : Former #Jeopardy contest...
# 3     1378654597057638402  RT @hotvickkrishna : How the mRNA Vaccine (Mod...
# 4     1378654537033117698  RT @hotvickkrishna : How the mRNA Vaccine (Mod...
# ...                   ...                                                ...
# 2053  1378512268980150276  RT @SanjayMehta_ : #computer लिया. वायरस आया. ...
# 2054  1378512253096443909  🚨Alas this continues to happen! Just TODAY ano...
# 2055  1378512142077464577  RT @Redpainter1 : I fully support your right t...
# 2056  1378512057440464901  RT @MoHFW_INDIA : #LargestVaccineDrive \n\nMor...
# 2057  1378511808965775361  I had a migraine every day after my first covi...
#
# ...

# %%
dataset.to_csv(r'C:\Users\Naman Bhoj\Desktop\Feb-April\in process 2021\cicn 2 mayank\data_with_class.csv')
